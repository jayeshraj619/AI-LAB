# %% [markdown]
# <a href="https://colab.research.google.com/github/jayeshraj619/AI-LAB/blob/master/blessle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/oldmonthtest1.csv')
df
# Out:
#           month      spi1       sl1  avg solar  avg R.HUM
# 0    01-10-1979  1.273802  0.143235  21.034567   0.660878
# 1    01-11-1979  2.145778  1.273802  18.618270   0.672347
# 2    01-12-1979  0.889794  2.145778  23.606018   0.632411
# 3    01-01-1980 -1.714817  0.889794  23.687354   0.680302
# 4    01-02-1980 -1.469306 -1.714817  22.860871   0.749740
# ..          ...       ...       ...        ...        ...
# 411  01-01-2014  0.317544  0.143235  12.783414   0.946414
# 412  01-02-2014  0.546507  0.317544  11.613665   0.959161
# 413  01-03-2014  0.629004  0.546507  21.052941   0.892296
# 414  01-04-2014  0.174373  0.629004  17.347204   0.902577
# 415  01-05-2014  1.144318  0.174373  19.994941   0.859645
#
# [416 rows x 5 columns]

# %%
 df['date_time'] = pd.to_datetime(df['month'], infer_datetime_format=True)

# %%
 df.index = pd.to_datetime(df['date_time'], format='%d.%m.%Y')
 df = df.drop(columns = ['month','date_time'])
 df
# Out:
#                 spi1       sl1  avg solar  avg R.HUM
# date_time
# 1979-01-10  1.273802  0.143235  21.034567   0.660878
# 1979-01-11  2.145778  1.273802  18.618270   0.672347
# 1979-01-12  0.889794  2.145778  23.606018   0.632411
# 1980-01-01 -1.714817  0.889794  23.687354   0.680302
# 1980-01-02 -1.469306 -1.714817  22.860871   0.749740
# ...              ...       ...        ...        ...
# 2014-01-01  0.317544  0.143235  12.783414   0.946414
# 2014-01-02  0.546507  0.317544  11.613665   0.959161
# 2014-01-03  0.629004  0.546507  21.052941   0.892296
# 2014-01-04  0.174373  0.629004  17.347204   0.902577
# 2014-01-05  1.144318  0.174373  19.994941   0.859645
#
# [416 rows x 4 columns]

# %%
def df_to_X_y2(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X, y = df_to_X_y2(df)
X.shape, y.shape
# Out:
# ((411, 5, 4), (411,))

# %%
X_train, y_train = X[:155], y[:155]
X_val, y_val = X[155:310], y[155:310]
X_test, y_test = X[310:], y[310:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((155, 5, 4), (155,), (155, 5, 4), (155,), (101, 5, 4), (101,))

# %%
temp_training_mean = np.mean(X_train[:, :, 0])
temp_training_std = np.std(X_train[:, :, 0])

                           
def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - temp_training_mean) / temp_training_std
  return X

temp_training_mean = np.mean(X_train[:, :, 1])
temp_training_std = np.std(X_train[:, :, 1])

                           
def preprocess(X):
  X[:, :, 1] = (X[:, :, 1] - temp_training_mean) / temp_training_std
  return X


temp_training_mean = np.mean(X_train[:, :, 2])
temp_training_std = np.std(X_train[:, :, 2])

                           
def preprocess(X):
  X[:, :, 2] = (X[:, :, 2] - temp_training_mean) / temp_training_std
  return X

temp_training_mean = np.mean(X_train[:, :, 3])
temp_training_std = np.std(X_train[:, :, 3])

                           
def preprocess(X):
  X[:, :, 3] = (X[:, :, 3] - temp_training_mean) / temp_training_std
  return X

temp_training_mean = np.mean(X_train[:, :, 3])
temp_training_std = np.std(X_train[:, :, 3])

                           
def preprocess(X):
  X[:, :, 3] = (X[:, :, 3] - temp_training_mean) / temp_training_std
  return X  
#temp_training_mean = np.mean(X_train[:, :, 4])
#temp_training_std = np.std(X_train[:, :, 4])

                           
#def preprocess(X):
#  X[:, :, 4] = (X[:, :, 4] - temp_training_mean) / temp_training_std
 # return X

# %%
preprocess(X_train)
preprocess(X_val)
preprocess(X_test)

# %%
p_training_mean3 = np.mean(X_train[:, :, 0])
p_training_std3 = np.std(X_train[:, :, 0])

def preprocess_output3(y):
  y[:] = (y[:] - p_training_mean3) / p_training_std3
  return y

# %%
preprocess_output3(y_train)
preprocess_output3(y_val)
preprocess_output3(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

model4 = Sequential()
model4.add(InputLayer((5, 4)))
model4.add(Bidirectional(LSTM(1000)))
model4.add(Dropout(0.5))
model4.add(Dropout(0.5))
model4.add(Dense(10, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()

# %%
cp4 = ModelCheckpoint('model4/', save_best_only=True)
model4.compile(loss="mse", optimizer=Adam(learning_rate=0.0001), metrics=['mse'])

# %%
early_stopping=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',min_delta=0.01,patience=2)
history=model4.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,batch_size=30)#,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 4s 709ms/step - loss: 0.5927 - mse: 0.5927 - val_loss: 0.7931 - val_mse: 0.7931
# Epoch 2/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.6115 - mse: 0.6115 - val_loss: 0.8101 - val_mse: 0.8101
# Epoch 3/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.6169 - mse: 0.6169 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 4/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5865 - mse: 0.5865 - val_loss: 0.7521 - val_mse: 0.7521
# Epoch 5/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.6448 - mse: 0.6448 - val_loss: 0.7648 - val_mse: 0.7648
# Epoch 6/100
# 6/6 [==============================] - 2s 423ms/step - loss: 0.6031 - mse: 0.6031 - val_loss: 0.7733 - val_mse: 0.7733
# Epoch 7/100
# 6/6 [==============================] - 2s 425ms/step - loss: 0.5918 - mse: 0.5918 - val_loss: 0.7580 - val_mse: 0.7580
# Epoch 8/100
# 6/6 [==============================] - 2s 430ms/step - loss: 0.6133 - mse: 0.6133 - val_loss: 0.7761 - val_mse: 0.7761
# Epoch 9/100
# 6/6 [==============================] - 2s 421ms/step - loss: 0.5981 - mse: 0.5981 - val_loss: 0.7485 - val_mse: 0.7485
# Epoch 10/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.5376 - mse: 0.5376 - val_loss: 0.7892 - val_mse: 0.7892
# Epoch 11/100
# 6/6 [==============================] - 2s 425ms/step - loss: 0.5789 - mse: 0.5789 - val_loss: 0.7709 - val_mse: 0.7709
# Epoch 12/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.5790 - mse: 0.5790 - val_loss: 0.7405 - val_mse: 0.7405
# Epoch 13/100
# 6/6 [==============================] - 2s 428ms/step - loss: 0.6229 - mse: 0.6229 - val_loss: 0.7144 - val_mse: 0.7144
# Epoch 14/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.5713 - mse: 0.5713 - val_loss: 0.7157 - val_mse: 0.7157
# Epoch 15/100
# 6/6 [==============================] - 2s 428ms/step - loss: 0.5981 - mse: 0.5981 - val_loss: 0.7121 - val_mse: 0.7121
# Epoch 16/100
# 6/6 [==============================] - 2s 423ms/step - loss: 0.6049 - mse: 0.6049 - val_loss: 0.7478 - val_mse: 0.7478
# Epoch 17/100
# 6/6 [==============================] - 2s 424ms/step - loss: 0.6444 - mse: 0.6444 - val_loss: 0.7807 - val_mse: 0.7807
# Epoch 18/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.6034 - mse: 0.6034 - val_loss: 0.7626 - val_mse: 0.7626
# Epoch 19/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.6163 - mse: 0.6163 - val_loss: 0.7266 - val_mse: 0.7266
# Epoch 20/100
# 6/6 [==============================] - 3s 437ms/step - loss: 0.5837 - mse: 0.5837 - val_loss: 0.7443 - val_mse: 0.7443
# Epoch 21/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5831 - mse: 0.5831 - val_loss: 0.7639 - val_mse: 0.7639
# Epoch 22/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.6009 - mse: 0.6009 - val_loss: 0.7394 - val_mse: 0.7394
# Epoch 23/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5951 - mse: 0.5951 - val_loss: 0.7546 - val_mse: 0.7546
# Epoch 24/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5938 - mse: 0.5938 - val_loss: 0.7450 - val_mse: 0.7450
# Epoch 25/100
# 6/6 [==============================] - 3s 432ms/step - loss: 0.5768 - mse: 0.5768 - val_loss: 0.7288 - val_mse: 0.7288
# Epoch 26/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.5909 - mse: 0.5909 - val_loss: 0.7408 - val_mse: 0.7408
# Epoch 27/100
# 6/6 [==============================] - 2s 419ms/step - loss: 0.5958 - mse: 0.5958 - val_loss: 0.7602 - val_mse: 0.7602
# Epoch 28/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5867 - mse: 0.5867 - val_loss: 0.7730 - val_mse: 0.7730
# Epoch 29/100
# 6/6 [==============================] - 2s 432ms/step - loss: 0.5808 - mse: 0.5808 - val_loss: 0.7920 - val_mse: 0.7920
# Epoch 30/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.5835 - mse: 0.5835 - val_loss: 0.7611 - val_mse: 0.7611
# Epoch 31/100
# 6/6 [==============================] - 2s 419ms/step - loss: 0.6089 - mse: 0.6089 - val_loss: 0.7556 - val_mse: 0.7556
# Epoch 32/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.5610 - mse: 0.5610 - val_loss: 0.7709 - val_mse: 0.7709
# Epoch 33/100
# 6/6 [==============================] - 2s 425ms/step - loss: 0.5999 - mse: 0.5999 - val_loss: 0.7624 - val_mse: 0.7624
# Epoch 34/100
# 6/6 [==============================] - 2s 427ms/step - loss: 0.5667 - mse: 0.5667 - val_loss: 0.7260 - val_mse: 0.7260
# Epoch 35/100
# 6/6 [==============================] - 2s 425ms/step - loss: 0.5809 - mse: 0.5809 - val_loss: 0.7079 - val_mse: 0.7079
# Epoch 36/100
# 6/6 [==============================] - 2s 434ms/step - loss: 0.6114 - mse: 0.6114 - val_loss: 0.7165 - val_mse: 0.7165
# Epoch 37/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5247 - mse: 0.5247 - val_loss: 0.7442 - val_mse: 0.7442
# Epoch 38/100
# 6/6 [==============================] - 2s 424ms/step - loss: 0.5752 - mse: 0.5752 - val_loss: 0.7739 - val_mse: 0.7739
# Epoch 39/100
# 6/6 [==============================] - 2s 419ms/step - loss: 0.5940 - mse: 0.5940 - val_loss: 0.8374 - val_mse: 0.8374
# Epoch 40/100
# 6/6 [==============================] - 2s 428ms/step - loss: 0.6288 - mse: 0.6288 - val_loss: 0.8281 - val_mse: 0.8281
# Epoch 41/100
# 6/6 [==============================] - 2s 435ms/step - loss: 0.5647 - mse: 0.5647 - val_loss: 0.7589 - val_mse: 0.7589
# Epoch 42/100
# 6/6 [==============================] - 2s 426ms/step - loss: 0.6344 - mse: 0.6344 - val_loss: 0.8064 - val_mse: 0.8064
# Epoch 43/100
# 6/6 [==============================] - 2s 428ms/step - loss: 0.6069 - mse: 0.6069 - val_loss: 0.7347 - val_mse: 0.7347
# Epoch 44/100
# 6/6 [==============================] - 2s 430ms/step - loss: 0.5924 - mse: 0.5924 - val_loss: 0.7197 - val_mse: 0.7197
# Epoch 45/100
# 6/6 [==============================] - 2s 435ms/step - loss: 0.5751 - mse: 0.5751 - val_loss: 0.7303 - val_mse: 0.7303
# Epoch 46/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.6007 - mse: 0.6007 - val_loss: 0.7597 - val_mse: 0.7597
# Epoch 47/100
# 6/6 [==============================] - 2s 435ms/step - loss: 0.5685 - mse: 0.5685 - val_loss: 0.7435 - val_mse: 0.7435
# Epoch 48/100
# 6/6 [==============================] - 3s 438ms/step - loss: 0.6015 - mse: 0.6015 - val_loss: 0.7105 - val_mse: 0.7105
# Epoch 49/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.5752 - mse: 0.5752 - val_loss: 0.7075 - val_mse: 0.7075
# Epoch 50/100
# 6/6 [==============================] - 3s 450ms/step - loss: 0.6123 - mse: 0.6123 - val_loss: 0.7134 - val_mse: 0.7134
# Epoch 51/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5717 - mse: 0.5717 - val_loss: 0.7022 - val_mse: 0.7022
# Epoch 52/100
# 6/6 [==============================] - 2s 423ms/step - loss: 0.6041 - mse: 0.6041 - val_loss: 0.7042 - val_mse: 0.7042
# Epoch 53/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5817 - mse: 0.5817 - val_loss: 0.7384 - val_mse: 0.7384
# Epoch 54/100
# 6/6 [==============================] - 2s 426ms/step - loss: 0.5684 - mse: 0.5684 - val_loss: 0.7376 - val_mse: 0.7376
# Epoch 55/100
# 6/6 [==============================] - 2s 422ms/step - loss: 0.5917 - mse: 0.5917 - val_loss: 0.7408 - val_mse: 0.7408
# Epoch 56/100
# 6/6 [==============================] - 2s 423ms/step - loss: 0.5840 - mse: 0.5840 - val_loss: 0.7741 - val_mse: 0.7741
# Epoch 57/100
# 6/6 [==============================] - 2s 423ms/step - loss: 0.5485 - mse: 0.5485 - val_loss: 0.7453 - val_mse: 0.7453
# Epoch 58/100
# 6/6 [==============================] - 3s 440ms/step - loss: 0.5746 - mse: 0.5746 - val_loss: 0.7387 - val_mse: 0.7387
# Epoch 59/100
# 6/6 [==============================] - 3s 441ms/step - loss: 0.5810 - mse: 0.5810 - val_loss: 0.7228 - val_mse: 0.7228
# Epoch 60/100
# 6/6 [==============================] - 2s 435ms/step - loss: 0.5687 - mse: 0.5687 - val_loss: 0.7539 - val_mse: 0.7539
# Epoch 61/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5763 - mse: 0.5763 - val_loss: 0.7627 - val_mse: 0.7627
# Epoch 62/100
# 6/6 [==============================] - 2s 434ms/step - loss: 0.5884 - mse: 0.5884 - val_loss: 0.7805 - val_mse: 0.7805
# Epoch 63/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5770 - mse: 0.5770 - val_loss: 0.7495 - val_mse: 0.7495
# Epoch 64/100
# 6/6 [==============================] - 2s 427ms/step - loss: 0.5997 - mse: 0.5997 - val_loss: 0.7352 - val_mse: 0.7352
# Epoch 65/100
# 6/6 [==============================] - 2s 436ms/step - loss: 0.5715 - mse: 0.5715 - val_loss: 0.7203 - val_mse: 0.7203
# Epoch 66/100
# 6/6 [==============================] - 3s 440ms/step - loss: 0.5725 - mse: 0.5725 - val_loss: 0.7582 - val_mse: 0.7582
# Epoch 67/100
# 6/6 [==============================] - 3s 434ms/step - loss: 0.5772 - mse: 0.5772 - val_loss: 0.7746 - val_mse: 0.7746
# Epoch 68/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.5459 - mse: 0.5459 - val_loss: 0.7951 - val_mse: 0.7951
# Epoch 69/100
# 6/6 [==============================] - 3s 439ms/step - loss: 0.5788 - mse: 0.5788 - val_loss: 0.7691 - val_mse: 0.7691
# Epoch 70/100
# 6/6 [==============================] - 3s 436ms/step - loss: 0.5472 - mse: 0.5472 - val_loss: 0.7145 - val_mse: 0.7145
# Epoch 71/100
# 6/6 [==============================] - 3s 439ms/step - loss: 0.5870 - mse: 0.5870 - val_loss: 0.6794 - val_mse: 0.6794
# Epoch 72/100
# 6/6 [==============================] - 3s 444ms/step - loss: 0.5886 - mse: 0.5886 - val_loss: 0.7286 - val_mse: 0.7286
# Epoch 73/100
# 6/6 [==============================] - 3s 436ms/step - loss: 0.6086 - mse: 0.6086 - val_loss: 0.7469 - val_mse: 0.7469
# Epoch 74/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.5821 - mse: 0.5821 - val_loss: 0.8017 - val_mse: 0.8017
# Epoch 75/100
# 6/6 [==============================] - 3s 449ms/step - loss: 0.5589 - mse: 0.5589 - val_loss: 0.8184 - val_mse: 0.8184
# Epoch 76/100
# 6/6 [==============================] - 3s 440ms/step - loss: 0.6178 - mse: 0.6178 - val_loss: 0.8040 - val_mse: 0.8040
# Epoch 77/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5350 - mse: 0.5350 - val_loss: 0.7713 - val_mse: 0.7713
# Epoch 78/100
# 6/6 [==============================] - 2s 426ms/step - loss: 0.5999 - mse: 0.5999 - val_loss: 0.7634 - val_mse: 0.7634
# Epoch 79/100
# 6/6 [==============================] - 2s 435ms/step - loss: 0.5603 - mse: 0.5603 - val_loss: 0.7551 - val_mse: 0.7551
# Epoch 80/100
# 6/6 [==============================] - 3s 437ms/step - loss: 0.5487 - mse: 0.5487 - val_loss: 0.7597 - val_mse: 0.7597
# Epoch 81/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5322 - mse: 0.5322 - val_loss: 0.7429 - val_mse: 0.7429
# Epoch 82/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.5994 - mse: 0.5994 - val_loss: 0.7255 - val_mse: 0.7255
# Epoch 83/100
# 6/6 [==============================] - 2s 434ms/step - loss: 0.5949 - mse: 0.5949 - val_loss: 0.7508 - val_mse: 0.7508
# Epoch 84/100
# 6/6 [==============================] - 2s 431ms/step - loss: 0.5714 - mse: 0.5714 - val_loss: 0.7206 - val_mse: 0.7206
# Epoch 85/100
# 6/6 [==============================] - 2s 425ms/step - loss: 0.5118 - mse: 0.5118 - val_loss: 0.7205 - val_mse: 0.7205
# Epoch 86/100
# 6/6 [==============================] - 2s 420ms/step - loss: 0.5877 - mse: 0.5877 - val_loss: 0.7598 - val_mse: 0.7598
# Epoch 87/100
# 6/6 [==============================] - 3s 443ms/step - loss: 0.6038 - mse: 0.6038 - val_loss: 0.7849 - val_mse: 0.7849
# Epoch 88/100
# 6/6 [==============================] - 3s 438ms/step - loss: 0.5554 - mse: 0.5554 - val_loss: 0.7544 - val_mse: 0.7544
# Epoch 89/100
# 6/6 [==============================] - 3s 439ms/step - loss: 0.5513 - mse: 0.5513 - val_loss: 0.7369 - val_mse: 0.7369
# Epoch 90/100
# 6/6 [==============================] - 2s 433ms/step - loss: 0.5459 - mse: 0.5459 - val_loss: 0.7079 - val_mse: 0.7079
# Epoch 91/100
# 6/6 [==============================] - 2s 434ms/step - loss: 0.5764 - mse: 0.5764 - val_loss: 0.7170 - val_mse: 0.7170
# Epoch 92/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.5601 - mse: 0.5601 - val_loss: 0.7639 - val_mse: 0.7639
# Epoch 93/100
# 6/6 [==============================] - 3s 441ms/step - loss: 0.5376 - mse: 0.5376 - val_loss: 0.8198 - val_mse: 0.8198
# Epoch 94/100
# 6/6 [==============================] - 3s 442ms/step - loss: 0.5657 - mse: 0.5657 - val_loss: 0.8068 - val_mse: 0.8068
# Epoch 95/100
# 6/6 [==============================] - 2s 434ms/step - loss: 0.5303 - mse: 0.5303 - val_loss: 0.7616 - val_mse: 0.7616
# Epoch 96/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.5378 - mse: 0.5378 - val_loss: 0.7522 - val_mse: 0.7522
# Epoch 97/100
# 6/6 [==============================] - 3s 443ms/step - loss: 0.5448 - mse: 0.5448 - val_loss: 0.8121 - val_mse: 0.8121
# Epoch 98/100
# 6/6 [==============================] - 2s 429ms/step - loss: 0.5702 - mse: 0.5702 - val_loss: 0.7072 - val_mse: 0.7072
# Epoch 99/100
# 6/6 [==============================] - 2s 432ms/step - loss: 0.5766 - mse: 0.5766 - val_loss: 0.7110 - val_mse: 0.7110
# Epoch 100/100
# 6/6 [==============================] - 3s 436ms/step - loss: 0.5764 - mse: 0.5764 - val_loss: 0.8159 - val_mse: 0.8159

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')

def postprocess_temp(arr):
  arr = (arr*temp_training_std) + temp_training_mean
  return arr

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  
  temp_preds = postprocess_temp(predictions)
  temp_actuals =postprocess_temp(y)
  print(predictions.shape)
  print(y.shape)
  df = pd.DataFrame(data={'SPI-1 Predictions': temp_preds,
                          'SPI-1 Actuals':temp_actuals,
                          })
  plt.plot(df['SPI-1 Predictions'][start:end])
  plt.plot(df['SPI-1 Actuals'][start:end])
  return df[start:end]

# %%
post_processed_df = plot_predictions2(model4, X_test, y_test)
post_processed_df
# Out:
# (101,)
# (101,)
#     SPI-1 Predictions  SPI-1 Actuals
# 0            0.761542       0.870034
# 1            0.765094       0.746093
# 2            0.844169       0.870034
# 3            0.897044       0.764958
# 4            0.837656       0.663060
# ..                ...            ...
# 95           0.555309       0.779689
# 96           0.685374       0.803349
# 97           0.765083       0.834427
# 98           0.856514       0.845624
# 99           0.932237       0.783916
#
# [100 rows x 2 columns]

# %%
import math 
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

mae1=mae(x,y)
mse1=mse((df['Temperature Actuals'][start:end]),(df['Temperature Predictions'][start:end]))
rmse1=np.sqrt(mse1)
r2 = r2_score((df['Temperature Actuals'][start:end]),(df['Temperature Predictions'][start:end]))
print('Mean square error =', mse1)
print('Mean absolute error =', mae1)
print('Root mean square error=', rmse1)
print('r2 score =', r2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temperature Predictions'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-b6c3af3c859a> in <module>()
#       2 from sklearn.metrics import mean_squared_error as mse
#       3 from sklearn.metrics import mean_absolute_error as mae
# ----> 4 x=(df['Temperature Predictions'][start:end])
#       5 y=(df['Temperature Actuals'][start:end])
#       6
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Temperature Predictions'

# %%
from sklearn.metrics import mean_squared_error as mse
import matplotlib.pyplot as plt
def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  print(predictions.shape)
  print(y.shape)
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
plot_predictions1(model4, X_test, y_test)
# Out:
# (107,)
# (107,)
# (     Predictions   Actuals
#  0       0.183951 -0.746416
#  1      -0.058177  0.370000
#  2       0.017963 -0.336389
#  3      -0.226638 -0.489013
#  4      -0.500716 -0.489013
#  ..           ...       ...
#  102    -0.930384  0.324249
#  103     0.174775  0.545929
#  104     0.836938  0.625802
#  105     0.857685  0.185632
#  106     0.534975  1.124725
#
#  [107 rows x 2 columns], 0.9775790004578795)
