# %% [markdown]
# <a href="https://colab.research.google.com/github/jayeshraj619/AI-LAB/blob/master/prjctLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
import math
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from keras.callbacks import EarlyStopping
df=pd.read_csv('/content/spi1full.csv',)
print('Number of rows and columns:', df.shape)
df.head(5)
# Out:
# Number of rows and columns: (421, 7)
#          date     spi    spi1    spi2    spi3  temp lag1   solar
# 0  01-01-1979 -1.0197 -1.2898  0.8088 -1.0197    36.6100 23.6060
# 1  01-02-1979  0.8088 -0.9092 -1.2898  0.8088    36.4474 23.6874
# 2  01-03-1979 -1.2898 -1.7148 -0.9092 -1.2898    32.6406 22.8609
# 3  01-04-1979 -0.9092 -0.8898 -1.7148 -0.9092    28.8777 19.3648
# 4  01-05-1979 -1.7148  0.8898 -0.8898 -1.7148    25.1810 14.7136

# %%
df['date_time'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       421 non-null    object
#  1   spi        421 non-null    float64
#  2   spi1       421 non-null    float64
#  3   spi2       421 non-null    float64
#  4   spi3       421 non-null    float64
#  5   temp lag1  421 non-null    float64
#  6   solar      421 non-null    float64
#  7   date_time  421 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 26.4+ KB

# %%
df['date_time']=pd.to_datetime(df['date_time']) 
df['year'] = df['date_time'].apply(lambda x: x.year)
df['quarter'] = df['date_time'].apply(lambda x: x.quarter)
df['month'] = df['date_time'].apply(lambda x: x.month)
df['day'] = df['date_time'].apply(lambda x: x.day)

# %%
df1=df.loc[:,['date_time','spi']]
df1.set_index('date_time',inplace=True)
df1.plot(figsize=(12,5))
plt.ylabel('spi1')
plt.legend().set_visible(False)
plt.tight_layout()
plt.title('+++')
sns.despine(top=True)
plt.show();

# %%
dataset = df.spi1.values #numpy.ndarray
dataset = dataset.astype('float32')
dataset = np.reshape(dataset, (-1, 1))
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train_size = int(len(dataset) * 0.40)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)
    
look_back = 1
X_train, Y_train = create_dataset(train, look_back)
X_test, Y_test = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, Y_train, epochs=100, batch_size=10, validation_data=(X_test, Y_test),verbose=2) 
model.summary()
model.save("boy")
# Out:
# Epoch 1/100
# 17/17 - 3s - loss: 0.2672 - val_loss: 0.2090 - 3s/epoch - 166ms/step
# Epoch 2/100
# 17/17 - 0s - loss: 0.1743 - val_loss: 0.1298 - 84ms/epoch - 5ms/step
# Epoch 3/100
# 17/17 - 0s - loss: 0.1064 - val_loss: 0.0736 - 98ms/epoch - 6ms/step
# Epoch 4/100
# 17/17 - 0s - loss: 0.0635 - val_loss: 0.0483 - 120ms/epoch - 7ms/step
# Epoch 5/100
# 17/17 - 0s - loss: 0.0493 - val_loss: 0.0442 - 118ms/epoch - 7ms/step
# Epoch 6/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0444 - 121ms/epoch - 7ms/step
# Epoch 7/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0445 - 100ms/epoch - 6ms/step
# Epoch 8/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0444 - 128ms/epoch - 8ms/step
# Epoch 9/100
# 17/17 - 0s - loss: 0.0475 - val_loss: 0.0445 - 128ms/epoch - 8ms/step
# Epoch 10/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0445 - 130ms/epoch - 8ms/step
# Epoch 11/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0445 - 104ms/epoch - 6ms/step
# Epoch 12/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0446 - 106ms/epoch - 6ms/step
# Epoch 13/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0448 - 100ms/epoch - 6ms/step
# Epoch 14/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0447 - 135ms/epoch - 8ms/step
# Epoch 15/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0448 - 132ms/epoch - 8ms/step
# Epoch 16/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0448 - 104ms/epoch - 6ms/step
# Epoch 17/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0449 - 122ms/epoch - 7ms/step
# Epoch 18/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0449 - 123ms/epoch - 7ms/step
# Epoch 19/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0450 - 137ms/epoch - 8ms/step
# Epoch 20/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0451 - 139ms/epoch - 8ms/step
# Epoch 21/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0451 - 127ms/epoch - 7ms/step
# Epoch 22/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0451 - 104ms/epoch - 6ms/step
# Epoch 23/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0452 - 102ms/epoch - 6ms/step
# Epoch 24/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0452 - 100ms/epoch - 6ms/step
# Epoch 25/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0453 - 129ms/epoch - 8ms/step
# Epoch 26/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0453 - 90ms/epoch - 5ms/step
# Epoch 27/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0453 - 92ms/epoch - 5ms/step
# Epoch 28/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0453 - 95ms/epoch - 6ms/step
# Epoch 29/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0453 - 111ms/epoch - 7ms/step
# Epoch 30/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0453 - 126ms/epoch - 7ms/step
# Epoch 31/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0454 - 92ms/epoch - 5ms/step
# Epoch 32/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0454 - 131ms/epoch - 8ms/step
# Epoch 33/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0455 - 131ms/epoch - 8ms/step
# Epoch 34/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0456 - 104ms/epoch - 6ms/step
# Epoch 35/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0455 - 127ms/epoch - 7ms/step
# Epoch 36/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0455 - 130ms/epoch - 8ms/step
# Epoch 37/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 110ms/epoch - 6ms/step
# Epoch 38/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 107ms/epoch - 6ms/step
# Epoch 39/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0456 - 107ms/epoch - 6ms/step
# Epoch 40/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0455 - 104ms/epoch - 6ms/step
# Epoch 41/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0457 - 105ms/epoch - 6ms/step
# Epoch 42/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0458 - 101ms/epoch - 6ms/step
# Epoch 43/100
# 17/17 - 0s - loss: 0.0468 - val_loss: 0.0456 - 122ms/epoch - 7ms/step
# Epoch 44/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 122ms/epoch - 7ms/step
# Epoch 45/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 91ms/epoch - 5ms/step
# Epoch 46/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0457 - 123ms/epoch - 7ms/step
# Epoch 47/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 90ms/epoch - 5ms/step
# Epoch 48/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0456 - 98ms/epoch - 6ms/step
# Epoch 49/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0458 - 99ms/epoch - 6ms/step
# Epoch 50/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0456 - 131ms/epoch - 8ms/step
# Epoch 51/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0458 - 133ms/epoch - 8ms/step
# Epoch 52/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 121ms/epoch - 7ms/step
# Epoch 53/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0456 - 90ms/epoch - 5ms/step
# Epoch 54/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 123ms/epoch - 7ms/step
# Epoch 55/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 108ms/epoch - 6ms/step
# Epoch 56/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0456 - 91ms/epoch - 5ms/step
# Epoch 57/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0456 - 95ms/epoch - 6ms/step
# Epoch 58/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 125ms/epoch - 7ms/step
# Epoch 59/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0457 - 119ms/epoch - 7ms/step
# Epoch 60/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0456 - 102ms/epoch - 6ms/step
# Epoch 61/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0456 - 125ms/epoch - 7ms/step
# Epoch 62/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 125ms/epoch - 7ms/step
# Epoch 63/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0456 - 104ms/epoch - 6ms/step
# Epoch 64/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0459 - 104ms/epoch - 6ms/step
# Epoch 65/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0457 - 97ms/epoch - 6ms/step
# Epoch 66/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0457 - 133ms/epoch - 8ms/step
# Epoch 67/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 132ms/epoch - 8ms/step
# Epoch 68/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 125ms/epoch - 7ms/step
# Epoch 69/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0456 - 96ms/epoch - 6ms/step
# Epoch 70/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 92ms/epoch - 5ms/step
# Epoch 71/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0458 - 125ms/epoch - 7ms/step
# Epoch 72/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0457 - 125ms/epoch - 7ms/step
# Epoch 73/100
# 17/17 - 0s - loss: 0.0477 - val_loss: 0.0457 - 101ms/epoch - 6ms/step
# Epoch 74/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 86ms/epoch - 5ms/step
# Epoch 75/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0458 - 91ms/epoch - 5ms/step
# Epoch 76/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0457 - 127ms/epoch - 7ms/step
# Epoch 77/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0456 - 90ms/epoch - 5ms/step
# Epoch 78/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 127ms/epoch - 7ms/step
# Epoch 79/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0456 - 131ms/epoch - 8ms/step
# Epoch 80/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0459 - 125ms/epoch - 7ms/step
# Epoch 81/100
# 17/17 - 0s - loss: 0.0474 - val_loss: 0.0457 - 126ms/epoch - 7ms/step
# Epoch 82/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 100ms/epoch - 6ms/step
# Epoch 83/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0456 - 132ms/epoch - 8ms/step
# Epoch 84/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0458 - 134ms/epoch - 8ms/step
# Epoch 85/100
# 17/17 - 0s - loss: 0.0478 - val_loss: 0.0457 - 95ms/epoch - 6ms/step
# Epoch 86/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 126ms/epoch - 7ms/step
# Epoch 87/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 97ms/epoch - 6ms/step
# Epoch 88/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0457 - 86ms/epoch - 5ms/step
# Epoch 89/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0459 - 118ms/epoch - 7ms/step
# Epoch 90/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0457 - 118ms/epoch - 7ms/step
# Epoch 91/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 101ms/epoch - 6ms/step
# Epoch 92/100
# 17/17 - 0s - loss: 0.0469 - val_loss: 0.0456 - 88ms/epoch - 5ms/step
# Epoch 93/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 124ms/epoch - 7ms/step
# Epoch 94/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0456 - 120ms/epoch - 7ms/step
# Epoch 95/100
# 17/17 - 0s - loss: 0.0471 - val_loss: 0.0456 - 96ms/epoch - 6ms/step
# Epoch 96/100
# 17/17 - 0s - loss: 0.0472 - val_loss: 0.0457 - 120ms/epoch - 7ms/step
# Epoch 97/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0460 - 126ms/epoch - 7ms/step
# Epoch 98/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 123ms/epoch - 7ms/step
# Epoch 99/100
# 17/17 - 0s - loss: 0.0473 - val_loss: 0.0457 - 131ms/epoch - 8ms/step
# Epoch 100/100
# 17/17 - 0s - loss: 0.0470 - val_loss: 0.0457 - 122ms/epoch - 7ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: boy/assets
# INFO:tensorflow:Assets written to: boy/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe344522e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# invert predictions
train_predict = scaler.inverse_transform(train_predict)
Y_train = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test = scaler.inverse_transform([Y_test])
#r2 = r2_score( train_predict[:,0], (Y_train[0])
#print('r2 score for a model which predicts mean value always is', r2)
print('Train Mean Absolute Error:', mae(Y_train[0], train_predict[:,0]))
print('Train Root Mean Squared Error:',np.sqrt(mse(Y_train[0], train_predict[:,0])))
print('Test Mean Absolute Error:', mae(Y_test[0], test_predict[:,0]))
print('Test Root Mean Squared Error:',np.sqrt(mse(Y_test[0], test_predict[:,0])))
# Out:
# Train Mean Absolute Error: 0.7523009340348457
# Train Root Mean Squared Error: 0.9335371643411439
# Test Mean Absolute Error: 0.7398389939445245
# Test Root Mean Squared Error: 0.9224359260076416

# %%
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(loc='upper right')
plt.show();

# %%
import math 
aa=[x for x in range(200)]
plt.figure(figsize=(8,4))
plt.plot(aa, Y_test[0][:200], marker='.', label="actual")
plt.plot(aa, test_predict[:,0][:200], 'r', label="prediction")
mae1=mae(Y_test[0][:200],test_predict[:,0][:200])
mse1=mse(Y_test[0][:200],test_predict[:,0][:200])
rmse1=np.sqrt(mse1)
r2 = r2_score( Y_test[0][:200], test_predict[:,0][:200])
print('Mean square error =', mse1)
print('Mean absolute error =', mae1)
print('Root mean square error=', rmse1)
print('r2 score =', r2)
# plt.tick_params(left=False, labelleft=True) #remove ticks
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('spi1', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();
# Out:
# Mean square error = 0.7835175406342734
# Mean absolute error = 0.7105043961299375
# Root mean square error= 0.8851652617643065
# r2 score = -0.0177542741501735
